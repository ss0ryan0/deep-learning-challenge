# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
app_df = application_df.drop(columns=['EIN'])
app_df
# Out:
#                                                     NAME APPLICATION_TYPE  \
# 0                           BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1                 AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2                     ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3                         SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4               GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
# ...                                                  ...              ...
# 34294              THE LIONS CLUB OF HONOLULU KAMEHAMEHA               T4
# 34295           INTERNATIONAL ASSOCIATION OF LIONS CLUBS               T4
# 34296                                PTA HAWAII CONGRESS               T3
# 34297  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...               T5
# 34298                           WATERHOUSE CHARITABLE TR               T3
#
#             AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# ...

# %%
# Determine the number of unique values in each column
app_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_counts = app_df['APPLICATION_TYPE'].value_counts()
app_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_counts[app_type_counts < 1000].index)
# app_df['App_Type_Bin'] = pd.cut(app_type_counts, bins=[0, cutoff_value, float('inf')], labels=['Low', 'High'])
# application_types_to_replace = app_type_counts[app_type_counts <= cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    app_df['APPLICATION_TYPE'] = app_df['APPLICATION_TYPE'].replace(app,"Other") #count combines into one value for that feature

# Check to make sure binning was successful
app_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = app_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts[class_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 1000].index)
# app_df['App_Type_Bin'] = pd.cut(class_counts, bins=[0, cutoff_value, float('inf')], labels=['Low', 'High'])
# classifications_to_replace = class_counts[class_counts <= cutoff_value].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    app_df['CLASSIFICATION'] = app_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
app_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
name_counts = application_df['NAME'].value_counts()
name_counts[name_counts > 300]
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
# PTA TEXAS CONGRESS                                  368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC       331
# ALPHA PHI SIGMA                                     313
# Name: NAME, dtype: int64

# %%
# Choose a cutoff value and create a list of names to be replaced
# use the variable name `classifications_to_replace`
names_to_replace = list(name_counts[name_counts < 300].index)
# app_df['App_Type_Bin'] = pd.cut(name_counts, bins=[0, cutoff_value, float('inf')], labels=['Low', 'High'])
# classifications_to_replace = name_counts[name_counts <= cutoff_value].index.tolist()

# Replace in dataframe
for name in names_to_replace:
    app_df['NAME'] = app_df['NAME'].replace(name,"Other")

# Check to make sure binning was successful
app_df['NAME'].value_counts()
# Out:
# Other                                              29662
# PARENT BOOSTER USA INC                              1260
# TOPS CLUB INC                                        765
# UNITED STATES BOWLING CONGRESS INC                   700
# WASHINGTON STATE UNIVERSITY                          492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC      408
# PTA TEXAS CONGRESS                                   368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC        331
# ALPHA PHI SIGMA                                      313
# Name: NAME, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_df_numeric = pd.get_dummies(app_df)
app_df_numeric
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  NAME_ALPHA PHI SIGMA  \
# 0           1      5000              1                     0
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  NAME_Other  \
# 0                                                      0              1
# 1                                                      0              1
# ...

# %%
# Split our preprocessed data into our features and target arrays
#refer to 20.2.05
#axis=0 is rows, axis=1 is columns
features = app_df_numeric.drop(columns=['IS_SUCCESSFUL'])
target = app_df_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num = len(X_train_scaled[0]) #number of rows


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=num))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                4000
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 6461 (25.24 KB)
# Trainable params: 6461 (25.24 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
nn

# %%
#  Create a callback
import os
from tensorflow.keras.callbacks import ModelCheckpoint
os.makedirs('AlphabetSoupCharity_Optimization/',exist_ok=True)
path = 'AlphabetSoupCharity_Optimization/weight.{epoch}.hdf5'
callback = ModelCheckpoint(filepath=path, save_weights_only=True, period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5417 - accuracy: 0.7311
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5274 - accuracy: 0.7392
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5238 - accuracy: 0.7414
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5222 - accuracy: 0.7429
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5208 - accuracy: 0.7444
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5199 - accuracy: 0.7441
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5190 - accuracy: 0.7442
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5176 - accuracy: 0.7442
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5177 - accuracy: 0.7451
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5257 - accuracy: 0.7392 - 693ms/epoch - 3ms/step
# Loss: 0.5256829261779785, Accuracy: 0.7392419576644897

# %%
# Export our model to HDF5 file
tf.keras.saving.save_model(nn, 'AlphabetSoupCharity_Optimization.h5')
# Out:
# <ipython-input-44-3f0dc79a700c>:2: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   tf.keras.saving.save_model(nn, 'my_model_2.h5')
